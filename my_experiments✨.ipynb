# %%
from generator.generator import Generator
from generator.font import *
import matplotlib.pyplot as plt
import numpy as np

g = Generator(lang='ru')
plt_dim = int(np.ceil(np.sqrt(g.N)))
fig, axs = plt.subplots(plt_dim, plt_dim, figsize=(20, 20))

for k in range(plt_dim):
    for j in range(plt_dim):
        s = g.generate_from_string(r'Недействительно', min_length=2, max_length=25, i = k * plt_dim + j) # get from a string
        if s:
            font_name = g.fonts[k * plt_dim + j].path
            axs[k, j].set_title(font_name[font_name.find('/'):])
            axs[k, j].imshow(s)
plt.show()
# Out:
# iptCTT.ttf
# istina.ttf
# _Eskal.ttf
# Chulok.ttf
# Script.otf
# erner4.ttf
# erner6.ttf
# erner7.ttf
# rner13.ttf
# rner14.ttf
# rner11.ttf
# rner15.ttf
# rner16.ttf
# rner17.ttf
# erner2.ttf
# erner3.ttf
# rner10.ttf
# rner30.ttf
# rner39.ttf
# rner40.ttf
# rner41.ttf
# rner42.ttf
# rner43.ttf
# arutya.ttf
# t\GOST.TTF
# GOST_0.TTF
# gost_a.ttf
# OST_AU.TTF
# gost_b.ttf
# OST_BU.TTF
# urve_b.ttf
# _curve.ttf
# alicmt.ttf
# rialmt.ttf
# alibri.ttf
# i_bold.ttf
# anpsmt.ttf
# egular.ttf
# roRu_0.ttf
# Bold_0.otf
# egular.otf
# egular.otf
# egular.otf
# cr-5.2.ttf
# e-Demo.ttf
# Faceto.otf
# eekend.otf
# egular.ttf
# egular.ttf
# Normal.otf
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 12
#      10 for k in range(plt_dim):
#      11     for j in range(plt_dim):
# ...
