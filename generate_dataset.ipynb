# %%
from generator.generator import Generator
from generator.font import *
import matplotlib.pyplot as plt

g = Generator(lang='ru')
s = g.generate_from_string(r'Недействительно', min_length=2, max_length=25, i=-3) # get from a string
s
# Out:
# c:\shiftlab_easy_ocr\generator\content\CruinnRegular.ttf
# <PIL.Image.Image image mode=RGBA size=407x86>
